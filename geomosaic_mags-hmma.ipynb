# %% [markdown]
# ### Downstream analysis for MAGSs-HMM Annotation, module: mags_hmm_annotation
# Raw reads count are aggregated for all the samples using the geomosaic command:
# ```bash
# geomosaic gather -s gmsetup -p
# ```
