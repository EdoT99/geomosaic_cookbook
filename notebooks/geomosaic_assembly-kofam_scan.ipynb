# %% [markdown]
# ## Downstream analysis for Assembly-KOFAM-scan with KEGG-DEcoder ##
# ```bash
# geomosaic gather -s gmsetup.yaml -p kofam_scan
# ```
# Create and activate the [KEGG-decoder](https://github.com/bjtully/BioData/blob/master/KEGGDecoder/README.md) environment. A more exhaustive guide is available on their site.
#
# ```bash
# conda env create -f kegg_decoder_environment.yaml
# conda activate keggdecoder
# ```
